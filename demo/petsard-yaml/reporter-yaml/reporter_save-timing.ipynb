# %% [markdown]
# # Environment setting / 環境設定

# %%
import os  # noqa: I001
import sys
from pathlib import Path


# Handle utils.py for Colab
if "COLAB_GPU" in os.environ:
    import urllib.request

    demo_utils_url = (
        "https://raw.githubusercontent.com/nics-tw/petsard/main/demo/demo_utils.py"
    )
    exec(urllib.request.urlopen(demo_utils_url).read().decode("utf-8"))
else:
    # demo_utils.py search for local
    for p in [Path.cwd()] + list(Path.cwd().parents)[:10]:
        utils_path = p / "demo_utils.py"
        if utils_path.exists() and "demo" in str(utils_path):
            sys.path.insert(0, str(p))
            exec(open(utils_path).read())
            break
# Out:
# 📂 Current working directory: demo/petsard-yaml/reporter-yaml
# ✅ PETsARD demo_utils loaded. Use quick_setup() to initialize.

# %% [markdown]
# ## Quick setup / 快速設定: Reporter YAML - Save Timing Information

# %%
from demo_utils import display_results, display_yaml_info, quick_setup  # noqa: I001
from petsard import Executor  # noqa: I001


is_colab, branch, yaml_path = quick_setup(
    config_file=[
        "reporter_save-timing.yaml",
    ],
    benchmark_data=None,
    petsard_branch="main",
)
# Out:
# ✅ Changed working directory to demo: petsard/demo
#    📁 Notebook location: demo/petsard-yaml/reporter-yaml/
#    🔍 YAML search priority:
#       1. demo/petsard-yaml/reporter-yaml/
#       2. demo/
#    💾 Output files will be saved in: demo/
# 🚀 PETsARD v1.7.0
# 📅 2025-10-17 16:33:56 UTC+8
# 🔧 Added to Python path: petsard/demo/petsard-yaml/reporter-yaml
# 📁 Processing configuration files from subfolder: petsard-yaml/reporter-yaml
# ✅ Found configuration (1/1): petsard/demo/petsard-yaml/reporter-yaml/reporter_save-timing.yaml

# %% [markdown]
# # Execution and Result / 執行與結果

# %% [markdown]
# ## Save Timing Information / 儲存時間資訊

# %%
display_yaml_info(yaml_path[0])
exec = Executor(yaml_path[0])
exec.run()
display_results(exec.get_result())
# Out:
# ============================================================
# 📋 YAML Configuration Files / YAML 設定檔案
# ============================================================
#
# 📄 File: reporter_save-timing.yaml
# 📁 Path: petsard/demo/petsard-yaml/reporter-yaml/reporter_save-timing.yaml
#
# ⚙️ Configuration content / 設定內容:
# ----------------------------------------
# ---
# Loader:
#   load_benchmark_with_schema:
#     filepath: benchmark://adult-income
#     schema: benchmark://adult-income_schema
# Splitter:
#   basic_split:
#     num_samples: 8
#     train_split_ratio: 0.8
# Preprocessor:
#   default:
#     method: default
#
# Synthesizer:
#   default:
#     method: default
#
#   petsard-gaussian-copula:
#     method: petsard-gaussian-copula
#
# Postprocessor:
#   default:
#     method: default
#
# Evaluator:
#   validity_check:
#     method: sdmetrics-diagnosticreport
#
#   fidelity_check:
#     method: sdmetrics-qualityreport
#
#   singling_out_risk:
#     method: anonymeter-singlingout
#     n_attacks: 400
#     n_cols: 3
#     max_attempts: 4000
#
#   classification_utility:
#     method: mlutility
#     task_type: classification
#     target: income
#     random_state: 42
#
# Reporter:
#   save_all_timing:
#     method: save_timing  # Required: Fixed as save_timing
#     # time_unit: seconds # Optional: Time unit (default: seconds)
#     # module:            # Optional: Specify modules to record
#     #   - Synthesizer
#     #   - Evaluator
#     # output: petsard    # Optional: Output filename prefix (default: petsard)
# ...
# ============================================================
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 187.79it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 551.23it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 77.99it/s]|
# Column Shapes Score: 95.2%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 206.48it/s]|
# Column Pair Trends Score: 60.95%
#
# Overall Score (Average): 78.08%
# Found 326 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 2 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 2 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.007232366431312513. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 685.69it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1766.77it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 93.20it/s]|
# Column Shapes Score: 95.54%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 235.59it/s]|
# Column Pair Trends Score: 58.32%
#
# Overall Score (Average): 76.93%
# Found 321 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 2 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 2 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.004756147167148254. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 716.85it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1784.81it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 101.07it/s]|
# Column Shapes Score: 95.18%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 241.78it/s]|
# Column Pair Trends Score: 61.24%
#
# Overall Score (Average): 78.21%
# Found 324 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 4 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 4 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.007232366431312513, baseline = 0.007232366431312513. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 716.98it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1672.37it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 96.09it/s]|
# Column Shapes Score: 95.44%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 240.92it/s]|
# Column Pair Trends Score: 58.29%
#
# Overall Score (Average): 76.86%
# Found 322 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 4 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 4 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.014661024223805288. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 704.62it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1763.79it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 99.92it/s]|
# Column Shapes Score: 94.98%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 246.21it/s]|
# Column Pair Trends Score: 59.79%
#
# Overall Score (Average): 77.39%
# Found 327 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 1 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 1 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# Found 345 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 2 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 2 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.004756147167148254. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 715.24it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1501.18it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 97.40it/s]|
# Column Shapes Score: 95.39%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 243.62it/s]|
# Column Pair Trends Score: 58.26%
#
# Overall Score (Average): 76.82%
# Found 336 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 4 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 4 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.004756147167148254. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 699.56it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1551.15it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 101.05it/s]|
# Column Shapes Score: 95.33%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 241.22it/s]|
# Column Pair Trends Score: 61.21%
#
# Overall Score (Average): 78.27%
# Found 323 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 1 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 1 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.007232366431312513. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 717.77it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1644.83it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 97.11it/s]|
# Column Shapes Score: 95.33%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 242.56it/s]|
# Column Pair Trends Score: 58.23%
#
# Overall Score (Average): 76.78%
# Found 340 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 3 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 3 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 711.07it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1869.12it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 99.52it/s]|
# Column Shapes Score: 95.26%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 240.04it/s]|
# Column Pair Trends Score: 60.97%
#
# Overall Score (Average): 78.11%
# Found 322 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 3 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 3 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.007232366431312513, baseline = 0.009708585695476772. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 700.47it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1533.57it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 95.99it/s]|
# Column Shapes Score: 95.35%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 222.68it/s]|
# Column Pair Trends Score: 58.26%
#
# Overall Score (Average): 76.8%
# Found 321 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 1 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 1 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.01218480495964103. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 717.26it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1775.74it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 101.10it/s]|
# Column Shapes Score: 95.26%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 238.34it/s]|
# Column Pair Trends Score: 60.81%
#
# Overall Score (Average): 78.03%
# Found 328 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 2 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 2 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.007232366431312513. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 721.64it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1600.27it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 96.60it/s]|
# Column Shapes Score: 95.49%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 244.52it/s]|
# Column Pair Trends Score: 58.31%
#
# Overall Score (Average): 76.9%
# Found 335 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 0 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 0 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.004756147167148254. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 720.39it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1760.83it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 102.32it/s]|
# Column Shapes Score: 95.2%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 243.45it/s]|
# Column Pair Trends Score: 61.04%
#
# Overall Score (Average): 78.12%
# Found 325 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 0 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 0 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.004756147167148254. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 700.38it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1808.67it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 97.39it/s]|
# Column Shapes Score: 95.55%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 243.02it/s]|
# Column Pair Trends Score: 58.38%
#
# Overall Score (Average): 76.97%
# Found 315 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 1 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 1 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.009708585695476772. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 698.23it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1720.39it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 97.32it/s]|
# Column Shapes Score: 95.3%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 238.93it/s]|
# Column Pair Trends Score: 61.24%
#
# Overall Score (Average): 78.27%
# Found 329 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 5 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 5 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.007232366431312513. Analysis results cannot be trusted.
#   self._sanity_check()
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 616.68it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 951.52it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 89.71it/s]|
# Column Shapes Score: 95.38%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 231.81it/s]|
# Column Pair Trends Score: 58.41%
#
# Overall Score (Average): 76.89%
# Found 326 failed queries out of 400. Check DEBUG messages for more details.
# Reached maximum number of attempts 4000 when generating singling out queries. Returning 2 instead of the requested 400.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 2 singling out queries out of the requested 400. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.004756147167148254, baseline = 0.007232366431312513. Analysis results cannot be trusted.
#   self._sanity_check()
# ================================================================================
# 📊 Execution Results / 執行結果
# ================================================================================
#
# [1] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-1]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [2] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-1]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [3] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-1]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [4] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-1]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [5] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-1]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [6] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-1]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [7] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-1]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [8] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-1]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [9] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-2]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [10] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-2]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [11] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-2]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [12] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-2]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [13] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-2]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [14] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-2]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [15] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-2]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [16] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-2]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [17] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-3]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [18] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-3]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [19] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-3]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [20] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-3]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [21] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-3]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [22] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-3]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [23] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-3]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [24] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-3]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [25] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-4]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [26] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-4]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [27] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-4]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [28] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-4]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [29] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-4]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [30] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-4]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [31] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-4]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [32] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-4]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [33] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-5]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [34] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-5]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [35] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-5]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [36] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-5]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [37] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-5]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [38] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-5]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [39] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-5]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [40] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-5]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [41] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-6]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [42] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-6]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [43] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-6]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [44] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-6]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [45] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-6]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [46] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-6]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [47] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-6]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [48] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-6]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [49] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-7]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [50] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-7]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [51] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-7]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [52] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-7]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [53] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-7]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [54] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-7]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [55] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-7]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [56] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-7]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [57] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-8]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [58] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-8]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [59] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-8]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [60] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-8]]_Preprocessor[default]_Synthesizer[default]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [61] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-8]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[validity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [62] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-8]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[fidelity_check]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [63] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-8]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[singling_out_risk]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# [64] Loader[load_benchmark_with_schema]_Splitter[basic_split_[8-8]]_Preprocessor[default]_Synthesizer[petsard-gaussian-copula]_Postprocessor[default]_Evaluator[classification_utility]_Reporter[save_all_timing]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • timing_report: DataFrame
#
# ================================================================================
# ✅ Total results / 總結果數: 64
# ================================================================================
