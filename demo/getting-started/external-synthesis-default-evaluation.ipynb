# %% [markdown]
# # Environment setting / 環境設定

# %%
import os  # noqa: I001
import sys
from pathlib import Path


# Handle utils.py for Colab
if "COLAB_GPU" in os.environ:
    import urllib.request

    demo_utils_url = (
        "https://raw.githubusercontent.com/nics-tw/petsard/main/demo/demo_utils.py"
    )
    exec(urllib.request.urlopen(demo_utils_url).read().decode("utf-8"))
else:
    # demo_utils.py search for local
    for p in [Path.cwd()] + list(Path.cwd().parents)[:10]:
        utils_path = p / "demo_utils.py"
        if utils_path.exists() and "demo" in str(utils_path):
            sys.path.insert(0, str(p))
            exec(open(utils_path).read())
            break
# Out:
# 📂 Current working directory: demo/getting-started
# ✅ PETsARD demo_utils loaded. Use quick_setup() to initialize.

# %% [markdown]
# ## Quick setup / 快速設定: Default Synthesis

# %%
from demo_utils import display_results, display_yaml_info, quick_setup  # noqa: I001
from petsard import Executor  # noqa: I001


is_colab, branch, yaml_path = quick_setup(
    config_file=[
        "external-synthesis-default-evaluation.yaml",
    ],
    benchmark_data=[
        "adult-income",
    ],
    petsard_branch="main",
)
# Out:
# ✅ Changed working directory to demo: petsard/demo
#    📁 Notebook location: demo/getting-started/
#    🔍 YAML search priority:
#       1. demo/getting-started/
#       2. demo/
#    💾 Output files will be saved in: demo/
# 🚀 PETsARD v1.7.0
# 📅 2025-10-18 11:11:11 UTC+8
# ✅ Loaded benchmark dataset: adult-income
# 🔧 Added to Python path: petsard/demo/getting-started
# 📁 Processing configuration files from subfolder: tutorial
# ✅ Found configuration (1/1): petsard/demo/getting-started/external-synthesis-default-evaluation.yaml

# %% [markdown]
# # Execution and Result / 執行與結果

# %% [markdown]
# ## Default Synthesis / 預設合成

# %%
display_yaml_info(yaml_path[0])
exec = Executor(yaml_path[0])
exec.run()
display_results(exec.get_result())
# Out:
# ============================================================
# 📋 YAML Configuration Files / YAML 設定檔案
# ============================================================
#
# 📄 File: external-synthesis-default-evaluation.yaml
# 📁 Path: petsard/demo/getting-started/external-synthesis-default-evaluation.yaml
#
# ⚙️ Configuration content / 設定內容:
# ----------------------------------------
# ---
# Splitter:
#   external_split:
#     method: custom_data
#     filepath:
#       ori: benchmark/adult-income_ori.csv
#       control: benchmark/adult-income_control.csv
# Synthesizer:
#   external_data:
#     method: custom_data
#     filepath: benchmark/adult-income_syn.csv
# Evaluator:
#   validity_check:
#     method: sdmetrics-diagnosticreport
#   fidelity_check:
#     method: sdmetrics-qualityreport
#   singling_out_risk:
#     method: anonymeter-singlingout
#   linkability_risk:
#     method: anonymeter-linkability
#     aux_cols:
#       -
#         - workclass
#         - education
#         - occupation
#         - race
#         - gender
#       -
#         - age
#         - marital-status
#         - relationship
#         - native-country
#         - income
#   inference_risk:
#     method: 'anonymeter-inference'
#     secret: 'income'
#   classification_utility:
#     method: mlutility
#     task_type: classification
#     target: income
# Reporter:
#   data:
#     method: 'save_data'
#     source: 'Postprocessor'
#   rpt:
#     method: 'save_report'
#     granularity:
#       - 'global'
#       - 'columnwise'
#       - 'pairwise'
#       - 'details'
# ...
# ============================================================
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 511.09it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 992.73it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 61.04it/s]|
# Column Shapes Score: 95.26%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 183.64it/s]|
# Column Pair Trends Score: 61.56%
#
# Overall Score (Average): 78.41%
# Found 1602 failed queries out of 2000. Check DEBUG messages for more details.
# Reached maximum number of attempts 500000 when generating singling out queries. Returning 148 instead of the requested 2000.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 148 singling out queries out of the requested 2000. This can probably lead to an underestimate of the singling out risk.
# ================================================================================
# 📊 Execution Results / 執行結果
# ================================================================================
#
# [1] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[validity_check]_Reporter[data]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
# ✅ Validation report saved to CSV file / 驗證報告已保存為 CSV 檔案
# 📁 Check the demo directory for petsard[Validation]_*.csv files
#    查看 demo 目錄中的 petsard[Validation]_*.csv 檔案
#
# [2] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[validity_check]_Reporter[rpt]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • [global]: DataFrame
#   • [columnwise]: DataFrame
#
# [3] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[fidelity_check]_Reporter[data]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
# ✅ Validation report saved to CSV file / 驗證報告已保存為 CSV 檔案
# 📁 Check the demo directory for petsard[Validation]_*.csv files
#    查看 demo 目錄中的 petsard[Validation]_*.csv 檔案
#
# [4] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[fidelity_check]_Reporter[rpt]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • [global]: DataFrame
#   • [columnwise]: DataFrame
#   • [pairwise]: DataFrame
#
# [5] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[singling_out_risk]_Reporter[data]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
# ✅ Validation report saved to CSV file / 驗證報告已保存為 CSV 檔案
# 📁 Check the demo directory for petsard[Validation]_*.csv files
#    查看 demo 目錄中的 petsard[Validation]_*.csv 檔案
#
# [6] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[singling_out_risk]_Reporter[rpt]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • [global]: DataFrame
#
# [7] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[linkability_risk]_Reporter[data]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
# ✅ Validation report saved to CSV file / 驗證報告已保存為 CSV 檔案
# 📁 Check the demo directory for petsard[Validation]_*.csv files
#    查看 demo 目錄中的 petsard[Validation]_*.csv 檔案
#
# [8] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[linkability_risk]_Reporter[rpt]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • [global]: DataFrame
#
# [9] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[inference_risk]_Reporter[data]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
# ✅ Validation report saved to CSV file / 驗證報告已保存為 CSV 檔案
# 📁 Check the demo directory for petsard[Validation]_*.csv files
#    查看 demo 目錄中的 petsard[Validation]_*.csv 檔案
#
# [10] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[inference_risk]_Reporter[rpt]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • [global]: DataFrame
#
# [11] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[classification_utility]_Reporter[data]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
# ✅ Validation report saved to CSV file / 驗證報告已保存為 CSV 檔案
# 📁 Check the demo directory for petsard[Validation]_*.csv files
#    查看 demo 目錄中的 petsard[Validation]_*.csv 檔案
#
# [12] Splitter[external_split_[1-1]]_Synthesizer[external_data]_Evaluator[classification_utility]_Reporter[rpt]
# ------------------------------------------------------------
# 📋 Reporter output / Reporter 輸出
#   • [global]: DataFrame
#
# ================================================================================
# ✅ Total results / 總結果數: 12
# ================================================================================
